# %%
import requests
import pandas as pd
import numpy
import pickle
import json

# %%
r = requests.get("https://api.darksky.net/forecast/9ae4fb3bd1f83bc1076d8f367b3d27b4/37.8267,-122.4233")
r.json()
# Out:
# {'latitude': 37.8267,
#  'longitude': -122.4233,
#  'timezone': 'America/Los_Angeles',
#  'currently': {'time': 1584815262,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'nearestStormDistance': 0,
#   'precipIntensity': 0.003,
#   'precipIntensityError': 0.001,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 55.46,
#   'apparentTemperature': 55.46,
#   'dewPoint': 42.68,
#   'humidity': 0.62,
#   'pressure': 1021.7,
#   'windSpeed': 3.83,
#   'windGust': 5.35,
#   'windBearing': 110,
#   'cloudCover': 0.28,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 375.6},
#  'minutely': {'summary': 'Possible drizzle starting in 15 min., stopping 30 min. later.',
#   'icon': 'rain',
#   'data': [{'time': 1584815220,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.06,
#     'precipType': 'rain'},
#    {'time': 1584815280,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
# ...

# %%
js = r.json()['hourly']['data']
js
# Out:
# [{'time': 1584813600,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0002,
#   'precipProbability': 0.14,
#   'precipType': 'rain',
#   'temperature': 54.45,
#   'apparentTemperature': 54.45,
#   'dewPoint': 42.75,
#   'humidity': 0.65,
#   'pressure': 1021.8,
#   'windSpeed': 3.75,
#   'windGust': 5.31,
#   'windBearing': 110,
#   'cloudCover': 0.28,
#   'uvIndex': 3,
#   'visibility': 10,
#   'ozone': 376.3},
#  {'time': 1584817200,
#   'summary': 'Possible Drizzle',
#   'icon': 'rain',
#   'precipIntensity': 0.0048,
#   'precipProbability': 0.48,
#   'precipType': 'rain',
#   'temperature': 56.65,
#   'apparentTemperature': 56.65,
#   'dewPoint': 42.42,
#   'humidity': 0.59,
#   'pressure': 1021.6,
#   'windSpeed': 4,
#   'windGust': 5.62,
#   'windBearing': 105,
#   'cloudCover': 0.28,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 374.3},
#  {'time': 1584820800,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
# ...

# %%
with open('test.json', 'w') as outfile:
    json.dump(js, outfile)

# %%
jspd = pd.read_json('test.json',orient='columns')

# %%
jspd
# Out:
#           time           summary                 icon  precipIntensity  \
# 0   1584813600             Clear            clear-day           0.0002
# 1   1584817200  Possible Drizzle                 rain           0.0048
# 2   1584820800             Clear            clear-day           0.0000
# 3   1584824400             Clear            clear-day           0.0018
# 4   1584828000             Clear            clear-day           0.0003
# 5   1584831600             Clear            clear-day           0.0004
# 6   1584835200             Clear            clear-day           0.0020
# 7   1584838800             Clear            clear-day           0.0005
# 8   1584842400             Clear            clear-day           0.0005
# 9   1584846000             Clear          clear-night           0.0004
# 10  1584849600             Clear          clear-night           0.0022
# 11  1584853200             Clear          clear-night           0.0003
# ...
